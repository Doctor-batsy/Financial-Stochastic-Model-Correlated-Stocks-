# %% [markdown]
# # Solution of Linear PDEs in High Dimensions : Option Pricing

# %% [markdown]
# ## Solution Method
# The approach relies on
#
# 1. the generation of training data by generating sample paths of the stochastic process $\{X_t\}_{t \in [0,T]}$
# 2. a neural network approximation of the unknown function $u(T,x) \approx u_\theta(x)$.

# %% [markdown]
# ### Step 2: Neural network approximation

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Activation, Input
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.callbacks import Callback
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd
from sklearn.metrics import r2_score
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
# Set data type
DTYPE='float32'
#DTYPE='float64'
tf.keras.backend.set_floatx(DTYPE)
print('TensorFlow version used: {}'.format(tf.__version__))
# Out:
# TensorFlow version used: 2.13.0

# %% [markdown]
# Next, we set some problem specific data.

# %%
performance = pd.read_csv("model_performance_GBM.csv")
# Create a subplot grid with two subplots side by side
plt.figure(figsize=(25, 10))

# Plot the blue line for "Approximation" and the horizontal line for "Exact Solution" on the first subplot
plt.plot(performance['Training_Loss'], color = 'b',label="Training_Loss", linewidth=0.7)
plt.plot(performance['Validation_Loss'], color = 'r',label="Validation_Loss", linewidth=0.7)

plt.xlabel('Epochs',fontsize="20")
plt.ylabel('Loss',fontsize="20")
plt.title('Training and Validation Loss')
plt.xticks(size = 20)
plt.yticks(size = 20)


# Customize the plot style
plt.style.use("seaborn")
plt.ylim(-0.1,5)
# plt.savefig("training_loss_plot_multi assets.jpg", format="jpeg", dpi = 500)
plt.legend(fontsize="20")
# Show the combined plot
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16272\3557489013.py:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.figure(figsize=(25, 10))
plt.plot(performance['Predicted_Values'], color = 'b',label="Predicted Values", linewidth=0.7)
# Create an array of the same length as the number of epochs for plotting the average target value
average_target_value_line = np.full_like(performance['Predicted_Values'], np.mean(Y))
plt.plot(average_target_value_line, linestyle='--', color='red', label='Average Target Value')
plt.ylim(247,254)
plt.xlabel('Epochs',fontsize="20")
plt.ylabel('Option Value',fontsize="20")
plt.title('Model Prediction',fontsize="23")
plt.xticks(size = 20)
plt.yticks(size = 20)


# Customize the plot style
plt.style.use("seaborn")
plt.legend(fontsize="20")
plt.savefig("solution GBM.jpg", format="jpeg", dpi = 500)
# Show the combined plot
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16272\2397449629.py:15: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
# Final time
T = tf.constant(1., dtype=DTYPE)

# Spatial dimensions
dim = 100

# Domain-of-interest at t=0
a = 90 * tf.ones((dim), dtype=DTYPE)
b = 110 * tf.ones((dim), dtype=DTYPE)

# Interest rate
r = tf.constant(1./20, dtype=DTYPE)

# Drift
mu = tf.constant(-1./20, dtype=DTYPE)

# Strike price
K = tf.constant(100., dtype=DTYPE)

# Diffusion/volatility
sigma = 1./10 + 1./200*tf.range(1, dim+1, dtype=DTYPE)

# Define terminal condition, i.e., payoff at maturity
def fun_g(x):
    return tf.exp(-r * T) * tf.maximum(tf.reduce_max(x, axis=1, keepdims=True), K)

# %%
def init_model(dim, activation='relu',
               num_hidden_neurons=200,
               num_hidden_layers=2,
               initializer=GlorotUniform()):
    model = Sequential()
    model.add(Input(shape=(dim,)))
    model.add(BatchNormalization(epsilon=1e-6))

    # Create a fixed number of hidden layers
    for _ in range(num_hidden_layers):
        model.add(Dense(num_hidden_neurons,
                        activation=None,
                        use_bias=False,
                        kernel_initializer=initializer))
        model.add(BatchNormalization(epsilon=1e-6))
        model.add(Activation(activation))

    model.add(Dense(1,
                    activation=None,
                    use_bias=False,
                    kernel_initializer=initializer))
    model.add(BatchNormalization(epsilon=1e-6))
    return model

# %% [markdown]
# ### 5. Solve the PDE

# %% [markdown]
# The model provided above uses a feed-forward neural network (FFNN) to approximate the solution of the Black-Scholes equation. Here's a high-level overview of how the model works:
#
# 1. **Input:** The input to the model is a set of starting values for the stochastic process X, which represents the underlying asset price in the Black-Scholes equation. These starting values are drawn randomly from a specified domain.
#
# 2. **Forward Pass:** The input is passed through the neural network model, which consists of multiple hidden layers with nonlinear activation functions. Each hidden layer applies a linear transformation to the input followed by the activation function.
#
# 3. **Output:** The output layer of the neural network produces a single scalar value, which represents the predicted price of the derivative based on the given input.
#
# 4. **Loss Function:** The model's predicted price is compared to the true price of the derivative using a loss function. In the provided code, the loss function is not explicitly defined, but it is likely a measure of the difference between the predicted price and the true price. The goal of training is to minimize this loss.
#
# 5. **Training:** The model is trained using a gradient-based optimization algorithm, such as the Adam optimizer, to update the weights and biases of the neural network. This optimization process iteratively adjusts the model's parameters to minimize the loss function.
#
# 6. **Evaluation:** After training, the model can be used to approximate the solution of the Black-Scholes equation for unseen inputs. The trained model takes the starting values as input and produces the predicted derivative price as output.
#
# By learning the underlying patterns and relationships in the training data, the neural network model can approximate the solution of the Black-Scholes equation and provide predictions for derivative prices based on new inputs.

# %%
#Euler
def draw_X(num_samples, a, b):
    dim = a.shape[0]

    X0 = a + tf.random.uniform((num_samples, dim), dtype=DTYPE) * (b-a)
    xi = tf.random.normal(shape=(num_samples, dim), dtype=DTYPE)
    XT = X0 * tf.exp( (mu- tf.square(sigma)/2) * T + sigma * tf.sqrt(T) * xi)

    # Return simulated paths
    return tf.stack([X0, XT], 2)

# %%
n_test = 80000
X = draw_X(n_test, a, b)
Xtest = X[:, :, 0]
Xtest = tf.convert_to_tensor(Xtest, dtype=DTYPE)
Y = tf.zeros((Xtest.shape[0], 1), dtype=DTYPE)  # Create an initial Ytest tensor filled with zeros
b_size = 32
mc_samples = 4000

def mc_step(y):

    Xi = tf.random.normal(shape=(b_size, dim), dtype=DTYPE)
    upd = tf.exp((mu - tf.square(sigma) / 2) * T + sigma * tf.sqrt(T) * Xi)
    XT = tf.reshape(Xtest, shape=[n_test, dim, 1]) * tf.transpose(upd)
    expected_payoff = tf.reduce_sum(tf.reshape(fun_g(XT), [n_test, b_size]), axis=1, keepdims=True)
    return y + expected_payoff / (b_size * mc_samples)


for i in range(mc_samples):
    if i%100==0:
        print(i,'/',mc_samples)
    Y=mc_step(Y)
# Out:
# 0 / 4000
# 100 / 4000
# 200 / 4000
# 300 / 4000
# 400 / 4000
# 500 / 4000
# 600 / 4000
# 700 / 4000
# 800 / 4000
# 900 / 4000
# 1000 / 4000
# 1100 / 4000
# 1200 / 4000
# 1300 / 4000
# 1400 / 4000
# 1500 / 4000
# 1600 / 4000
# 1700 / 4000
# 1800 / 4000
# 1900 / 4000
# 2000 / 4000
# 2100 / 4000
# 2200 / 4000
# 2300 / 4000
# 2400 / 4000
# 2500 / 4000
# 2600 / 4000
# 2700 / 4000
# 2800 / 4000
# 2900 / 4000
# 3000 / 4000
# 3100 / 4000
# 3200 / 4000
# 3300 / 4000
# 3400 / 4000
# 3500 / 4000
# 3600 / 4000
# 3700 / 4000
# 3800 / 4000
# 3900 / 4000

# %%
np.mean(Y)
# Out:
# 253.07613

# %%
Ytest = np.array(Y)
df = pd.DataFrame(Xtest)
df['Y'] = Ytest
X_train_val, X_test, y_train_val, y_test = train_test_split(df.drop(columns=['Y']), df.loc[:, 'Y'], test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
# Define the model
model = init_model(dim=dim)

# Learning rate schedule and optimizer
lr = tf.keras.optimizers.schedules.PiecewiseConstantDecay([100, 200], [2e-3, 1e-6, 1e-8])
optimizer = tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
#optimizer = tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-8)


# Compile the model
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_96 (Ba  (None, 100)               400
#  tchNormalization)
#
#  dense_72 (Dense)            (None, 200)               20000
#
#  batch_normalization_97 (Ba  (None, 200)               800
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 200)               0
#
#  dense_73 (Dense)            (None, 200)               40000
#
#  batch_normalization_98 (Ba  (None, 200)               800
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 200)               0
#
#  dense_74 (Dense)            (None, 1)                 200
#
#  batch_normalization_99 (Ba  (None, 1)                 4
#  tchNormalization)
#
# =================================================================
# Total params: 62204 (242.98 KB)
# Trainable params: 61202 (239.07 KB)
# Non-trainable params: 1002 (3.91 KB)
# _________________________________________________________________
# c:\Users\pc\anaconda3\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
class CustomCallback(Callback):
    def on_train_begin(self, logs=None):
        self.epoch_times = []
        self.train_losses = []
        self.val_losses = []
        self.predictions = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

        # Save the losses
        self.train_losses.append(logs['loss'])
        self.val_losses.append(logs['val_loss'])

        # Assuming we want to make and save predictions on the validation data
        predictions = self.model.predict(X_val).flatten()
        self.predictions.append(predictions[-1])  # Save the last prediction

# Initialize the callback
custom_callback = CustomCallback()

# %%
# Fit the model with the custom callback
start_time = time.time()
history = model.fit(
    X_train, 
    y_train, 
    batch_size=128, 
    epochs=500,  # Make sure this is the desired number of epochs
    validation_data=(X_val, y_val), 
    callbacks=[custom_callback]  # Corrected here
)
end_time = time.time()
total_time = end_time - start_time
# Out:
# Epoch 1/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 2s 20ms/step - loss: 17611.1543 - val_loss: 59701.8242
# Epoch 2/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 5.4826 - val_loss: 10564.7998
# Epoch 3/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9545 - val_loss: 2284.1389
# Epoch 4/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9262 - val_loss: 588.7164
# Epoch 5/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9269 - val_loss: 164.2027
# Epoch 6/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9203 - val_loss: 50.1866
# Epoch 7/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9162 - val_loss: 17.9436
# Epoch 8/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9069 - val_loss: 7.9604
# Epoch 9/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9025 - val_loss: 4.4743
# Epoch 10/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 15ms/step - loss: 1.9171 - val_loss: 3.0867
# Epoch 11/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9159 - val_loss: 2.4671
# Epoch 12/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9242 - val_loss: 2.1763
# Epoch 13/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9174 - val_loss: 2.0386
# Epoch 14/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9211 - val_loss: 1.9661
# Epoch 15/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9115 - val_loss: 1.9171
# Epoch 16/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9170 - val_loss: 1.9240
# Epoch 17/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9187 - val_loss: 1.9136
# Epoch 18/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9150 - val_loss: 1.9019
# Epoch 19/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9209 - val_loss: 1.9183
# Epoch 20/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9051 - val_loss: 1.9084
# Epoch 21/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9371 - val_loss: 1.8939
# Epoch 22/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9099 - val_loss: 1.8878
# Epoch 23/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9328 - val_loss: 1.8933
# Epoch 24/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9211 - val_loss: 1.8944
# Epoch 25/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9258 - val_loss: 1.8835
# Epoch 26/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9304 - val_loss: 1.8929
# Epoch 27/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9166 - val_loss: 1.8978
# Epoch 28/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9062 - val_loss: 1.8894
# Epoch 29/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9094 - val_loss: 1.8949
# Epoch 30/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9315 - val_loss: 1.8950
# Epoch 31/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9236 - val_loss: 1.8903
# Epoch 32/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9204 - val_loss: 1.8885
# Epoch 33/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9140 - val_loss: 1.8955
# Epoch 34/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9182 - val_loss: 1.9001
# Epoch 35/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9181 - val_loss: 1.9006
# Epoch 36/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9113 - val_loss: 1.8983
# Epoch 37/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9221 - val_loss: 1.9098
# Epoch 38/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9313 - val_loss: 1.9029
# Epoch 39/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9156 - val_loss: 1.9013
# Epoch 40/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9240 - val_loss: 1.8980
# Epoch 41/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9229 - val_loss: 1.9042
# Epoch 42/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9215 - val_loss: 1.8902
# Epoch 43/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9100 - val_loss: 1.8943
# Epoch 44/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9213 - val_loss: 1.8859
# Epoch 45/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9102 - val_loss: 1.8842
# Epoch 46/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9300 - val_loss: 1.8876
# Epoch 47/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9158 - val_loss: 1.8810
# Epoch 48/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9394 - val_loss: 1.8689
# Epoch 49/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9138 - val_loss: 1.8809
# Epoch 50/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9402 - val_loss: 1.8926
# Epoch 51/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9191 - val_loss: 1.8851
# Epoch 52/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9221 - val_loss: 1.8906
# Epoch 53/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9331 - val_loss: 1.8914
# Epoch 54/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9101 - val_loss: 1.8787
# Epoch 55/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9163 - val_loss: 1.8765
# Epoch 56/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9281 - val_loss: 1.8769
# Epoch 57/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9163 - val_loss: 1.8864
# Epoch 58/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9218 - val_loss: 1.8822
# Epoch 59/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9207 - val_loss: 1.8794
# Epoch 60/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9182 - val_loss: 1.8805
# Epoch 61/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9118 - val_loss: 1.8805
# Epoch 62/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9140 - val_loss: 1.8858
# Epoch 63/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9228 - val_loss: 1.8850
# Epoch 64/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9104 - val_loss: 1.8865
# Epoch 65/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9302 - val_loss: 1.8896
# Epoch 66/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9211 - val_loss: 1.8870
# Epoch 67/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9255 - val_loss: 1.8958
# Epoch 68/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9109 - val_loss: 1.8981
# Epoch 69/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9200 - val_loss: 1.8970
# Epoch 70/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9096 - val_loss: 1.9064
# Epoch 71/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9084 - val_loss: 1.8978
# Epoch 72/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9187 - val_loss: 1.8929
# Epoch 73/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9143 - val_loss: 1.8889
# Epoch 74/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9291 - val_loss: 1.8869
# Epoch 75/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9185 - val_loss: 1.8895
# Epoch 76/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9158 - val_loss: 1.8938
# Epoch 77/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9162 - val_loss: 1.8978
# Epoch 78/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9131 - val_loss: 1.8975
# Epoch 79/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9254 - val_loss: 1.9025
# Epoch 80/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9165 - val_loss: 1.8928
# Epoch 81/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9104 - val_loss: 1.9042
# Epoch 82/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9140 - val_loss: 1.8928
# Epoch 83/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9194 - val_loss: 1.8904
# Epoch 84/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9181 - val_loss: 1.8968
# Epoch 85/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9191 - val_loss: 1.8894
# Epoch 86/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9258 - val_loss: 1.8858
# Epoch 87/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9201 - val_loss: 1.8888
# Epoch 88/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9200 - val_loss: 1.8844
# Epoch 89/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9163 - val_loss: 1.9069
# Epoch 90/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9213 - val_loss: 1.8934
# Epoch 91/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9133 - val_loss: 1.8946
# Epoch 92/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9137 - val_loss: 1.8935
# Epoch 93/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9295 - val_loss: 1.8999
# Epoch 94/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9221 - val_loss: 1.8979
# Epoch 95/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 16ms/step - loss: 1.9316 - val_loss: 1.8980
# Epoch 96/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9348 - val_loss: 1.8932
# Epoch 97/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9148 - val_loss: 1.8910
# Epoch 98/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9349 - val_loss: 1.8960
# Epoch 99/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9228 - val_loss: 1.8960
# Epoch 100/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9352 - val_loss: 1.8943
# Epoch 101/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9315 - val_loss: 1.8895
# Epoch 102/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9182 - val_loss: 1.8904
# Epoch 103/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9223 - val_loss: 1.8832
# Epoch 104/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9243 - val_loss: 1.9063
# Epoch 105/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9231 - val_loss: 1.9047
# Epoch 106/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9087 - val_loss: 1.9011
# Epoch 107/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9107 - val_loss: 1.8890
# Epoch 108/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9131 - val_loss: 1.8990
# Epoch 109/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9146 - val_loss: 1.8973
# Epoch 110/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9151 - val_loss: 1.8983
# Epoch 111/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9159 - val_loss: 1.9006
# Epoch 112/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9178 - val_loss: 1.9012
# Epoch 113/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9134 - val_loss: 1.9051
# Epoch 114/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9200 - val_loss: 1.9073
# Epoch 115/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9172 - val_loss: 1.9017
# Epoch 116/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9328 - val_loss: 1.8944
# Epoch 117/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9260 - val_loss: 1.8885
# Epoch 118/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9100 - val_loss: 1.8936
# Epoch 119/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9057 - val_loss: 1.8981
# Epoch 120/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9190 - val_loss: 1.8934
# Epoch 121/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9201 - val_loss: 1.9043
# Epoch 122/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9181 - val_loss: 1.8976
# Epoch 123/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9192 - val_loss: 1.8939
# Epoch 124/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9360 - val_loss: 1.8855
# Epoch 125/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9120 - val_loss: 1.8999
# Epoch 126/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9098 - val_loss: 1.8909
# Epoch 127/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9141 - val_loss: 1.9000
# Epoch 128/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9149 - val_loss: 1.9068
# Epoch 129/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9273 - val_loss: 1.8963
# Epoch 130/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9033 - val_loss: 1.8865
# Epoch 131/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9076 - val_loss: 1.8853
# Epoch 132/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9233 - val_loss: 1.8876
# Epoch 133/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9282 - val_loss: 1.8786
# Epoch 134/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9065 - val_loss: 1.8876
# Epoch 135/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9211 - val_loss: 1.8946
# Epoch 136/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9253 - val_loss: 1.8915
# Epoch 137/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9306 - val_loss: 1.8805
# Epoch 138/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9198 - val_loss: 1.8879
# Epoch 139/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9129 - val_loss: 1.8918
# Epoch 140/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9137 - val_loss: 1.8940
# Epoch 141/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9331 - val_loss: 1.8890
# Epoch 142/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9253 - val_loss: 1.8877
# Epoch 143/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9115 - val_loss: 1.8836
# Epoch 144/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9431 - val_loss: 1.8890
# Epoch 145/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9166 - val_loss: 1.8964
# Epoch 146/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9237 - val_loss: 1.8978
# Epoch 147/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9131 - val_loss: 1.8990
# Epoch 148/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9198 - val_loss: 1.8870
# Epoch 149/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9111 - val_loss: 1.8823
# Epoch 150/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9165 - val_loss: 1.8917
# Epoch 151/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9179 - val_loss: 1.8945
# Epoch 152/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9124 - val_loss: 1.8970
# Epoch 153/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9075 - val_loss: 1.8991
# Epoch 154/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9305 - val_loss: 1.8939
# Epoch 155/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9275 - val_loss: 1.8863
# Epoch 156/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9270 - val_loss: 1.8824
# Epoch 157/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9104 - val_loss: 1.8911
# Epoch 158/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9209 - val_loss: 1.8780
# Epoch 159/500
# 250/250 [==============================] - 1s 5ms/step
# 63/63 [==============================] - 3s 52ms/step - loss: 1.9208 - val_loss: 1.8935
# Epoch 160/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9142 - val_loss: 1.8932
# Epoch 161/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9150 - val_loss: 1.8883
# Epoch 162/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9151 - val_loss: 1.8963
# Epoch 163/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9325 - val_loss: 1.8946
# Epoch 164/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9197 - val_loss: 1.8951
# Epoch 165/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9150 - val_loss: 1.8989
# Epoch 166/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9151 - val_loss: 1.8898
# Epoch 167/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9136 - val_loss: 1.8928
# Epoch 168/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9195 - val_loss: 1.9065
# Epoch 169/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9307 - val_loss: 1.9006
# Epoch 170/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9199 - val_loss: 1.8963
# Epoch 171/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9148 - val_loss: 1.9003
# Epoch 172/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9177 - val_loss: 1.9040
# Epoch 173/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9171 - val_loss: 1.8897
# Epoch 174/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9193 - val_loss: 1.8957
# Epoch 175/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9125 - val_loss: 1.8966
# Epoch 176/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9228 - val_loss: 1.8889
# Epoch 177/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9149 - val_loss: 1.9005
# Epoch 178/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9090 - val_loss: 1.9044
# Epoch 179/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9227 - val_loss: 1.8965
# Epoch 180/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9079 - val_loss: 1.9024
# Epoch 181/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9107 - val_loss: 1.8942
# Epoch 182/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9087 - val_loss: 1.8837
# Epoch 183/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9307 - val_loss: 1.8954
# Epoch 184/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9227 - val_loss: 1.8849
# Epoch 185/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9155 - val_loss: 1.8819
# Epoch 186/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9075 - val_loss: 1.8875
# Epoch 187/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9297 - val_loss: 1.8980
# Epoch 188/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9030 - val_loss: 1.9003
# Epoch 189/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9132 - val_loss: 1.9100
# Epoch 190/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9139 - val_loss: 1.8975
# Epoch 191/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9108 - val_loss: 1.8883
# Epoch 192/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9230 - val_loss: 1.8860
# Epoch 193/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9241 - val_loss: 1.9076
# Epoch 194/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9248 - val_loss: 1.9033
# Epoch 195/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9208 - val_loss: 1.8937
# Epoch 196/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9218 - val_loss: 1.8934
# Epoch 197/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9097 - val_loss: 1.8910
# Epoch 198/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9296 - val_loss: 1.8865
# Epoch 199/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9140 - val_loss: 1.8896
# Epoch 200/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9160 - val_loss: 1.8794
# Epoch 201/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9471 - val_loss: 1.8827
# Epoch 202/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9223 - val_loss: 1.8891
# Epoch 203/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9156 - val_loss: 1.8847
# Epoch 204/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9240 - val_loss: 1.8840
# Epoch 205/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9300 - val_loss: 1.8914
# Epoch 206/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9194 - val_loss: 1.8792
# Epoch 207/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9094 - val_loss: 1.8932
# Epoch 208/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 33ms/step - loss: 1.9215 - val_loss: 1.8858
# Epoch 209/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9044 - val_loss: 1.8905
# Epoch 210/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9181 - val_loss: 1.8980
# Epoch 211/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9175 - val_loss: 1.8902
# Epoch 212/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9203 - val_loss: 1.8954
# Epoch 213/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9183 - val_loss: 1.9105
# Epoch 214/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9111 - val_loss: 1.9065
# Epoch 215/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9086 - val_loss: 1.8927
# Epoch 216/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9127 - val_loss: 1.8903
# Epoch 217/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9163 - val_loss: 1.8888
# Epoch 218/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9163 - val_loss: 1.8921
# Epoch 219/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9227 - val_loss: 1.8921
# Epoch 220/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 36ms/step - loss: 1.9196 - val_loss: 1.8885
# Epoch 221/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9239 - val_loss: 1.8900
# Epoch 222/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9195 - val_loss: 1.8928
# Epoch 223/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9232 - val_loss: 1.8896
# Epoch 224/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9291 - val_loss: 1.8836
# Epoch 225/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9167 - val_loss: 1.8827
# Epoch 226/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9199 - val_loss: 1.8976
# Epoch 227/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9216 - val_loss: 1.8946
# Epoch 228/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9287 - val_loss: 1.9005
# Epoch 229/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9306 - val_loss: 1.8886
# Epoch 230/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9181 - val_loss: 1.8968
# Epoch 231/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9203 - val_loss: 1.9004
# Epoch 232/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9151 - val_loss: 1.8899
# Epoch 233/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9172 - val_loss: 1.8880
# Epoch 234/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9171 - val_loss: 1.8895
# Epoch 235/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9271 - val_loss: 1.8918
# Epoch 236/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9210 - val_loss: 1.8862
# Epoch 237/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9149 - val_loss: 1.8989
# Epoch 238/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9309 - val_loss: 1.8931
# Epoch 239/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9313 - val_loss: 1.9022
# Epoch 240/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9216 - val_loss: 1.9040
# Epoch 241/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9256 - val_loss: 1.9009
# Epoch 242/500
# 250/250 [==============================] - 1s 5ms/step
# 63/63 [==============================] - 2s 37ms/step - loss: 1.9148 - val_loss: 1.8949
# Epoch 243/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 3s 49ms/step - loss: 1.9237 - val_loss: 1.8811
# Epoch 244/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9236 - val_loss: 1.8978
# Epoch 245/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9372 - val_loss: 1.8977
# Epoch 246/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9161 - val_loss: 1.8926
# Epoch 247/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9125 - val_loss: 1.8974
# Epoch 248/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9214 - val_loss: 1.8917
# Epoch 249/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9294 - val_loss: 1.8840
# Epoch 250/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9117 - val_loss: 1.8778
# Epoch 251/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9262 - val_loss: 1.8768
# Epoch 252/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9157 - val_loss: 1.8874
# Epoch 253/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9189 - val_loss: 1.8852
# Epoch 254/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 2s 36ms/step - loss: 1.9212 - val_loss: 1.9036
# Epoch 255/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9132 - val_loss: 1.9104
# Epoch 256/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9115 - val_loss: 1.9030
# Epoch 257/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9277 - val_loss: 1.8971
# Epoch 258/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9261 - val_loss: 1.8968
# Epoch 259/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9125 - val_loss: 1.8841
# Epoch 260/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9136 - val_loss: 1.8927
# Epoch 261/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9126 - val_loss: 1.8894
# Epoch 262/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9186 - val_loss: 1.8822
# Epoch 263/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9064 - val_loss: 1.8830
# Epoch 264/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9207 - val_loss: 1.8828
# Epoch 265/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9203 - val_loss: 1.8898
# Epoch 266/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9198 - val_loss: 1.8810
# Epoch 267/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9156 - val_loss: 1.8870
# Epoch 268/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9120 - val_loss: 1.8868
# Epoch 269/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9151 - val_loss: 1.8988
# Epoch 270/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9205 - val_loss: 1.9070
# Epoch 271/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9146 - val_loss: 1.9035
# Epoch 272/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9124 - val_loss: 1.8819
# Epoch 273/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9176 - val_loss: 1.8801
# Epoch 274/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9183 - val_loss: 1.8837
# Epoch 275/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9115 - val_loss: 1.8795
# Epoch 276/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9239 - val_loss: 1.8869
# Epoch 277/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9246 - val_loss: 1.8904
# Epoch 278/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9292 - val_loss: 1.9034
# Epoch 279/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9291 - val_loss: 1.8949
# Epoch 280/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9264 - val_loss: 1.9029
# Epoch 281/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9130 - val_loss: 1.9028
# Epoch 282/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9128 - val_loss: 1.8909
# Epoch 283/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9121 - val_loss: 1.9009
# Epoch 284/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9144 - val_loss: 1.8857
# Epoch 285/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9294 - val_loss: 1.8822
# Epoch 286/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9357 - val_loss: 1.8985
# Epoch 287/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9150 - val_loss: 1.9019
# Epoch 288/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9292 - val_loss: 1.8994
# Epoch 289/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9309 - val_loss: 1.9020
# Epoch 290/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9182 - val_loss: 1.8993
# Epoch 291/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9134 - val_loss: 1.9032
# Epoch 292/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9164 - val_loss: 1.8973
# Epoch 293/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9209 - val_loss: 1.8912
# Epoch 294/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9192 - val_loss: 1.8822
# Epoch 295/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9213 - val_loss: 1.8843
# Epoch 296/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9185 - val_loss: 1.8821
# Epoch 297/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9208 - val_loss: 1.8863
# Epoch 298/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9281 - val_loss: 1.8884
# Epoch 299/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9168 - val_loss: 1.8905
# Epoch 300/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9254 - val_loss: 1.8954
# Epoch 301/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9209 - val_loss: 1.8945
# Epoch 302/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9144 - val_loss: 1.8836
# Epoch 303/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9081 - val_loss: 1.8873
# Epoch 304/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9144 - val_loss: 1.8969
# Epoch 305/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9179 - val_loss: 1.8954
# Epoch 306/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9323 - val_loss: 1.9027
# Epoch 307/500
# ...
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9223 - val_loss: 1.8932
# Epoch 400/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9195 - val_loss: 1.8909
# Epoch 401/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9125 - val_loss: 1.8777
# Epoch 402/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9238 - val_loss: 1.8814
# Epoch 403/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9237 - val_loss: 1.8842
# Epoch 404/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9179 - val_loss: 1.8821
# Epoch 405/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9165 - val_loss: 1.8883
# Epoch 406/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9141 - val_loss: 1.8865
# Epoch 407/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9100 - val_loss: 1.8947
# Epoch 408/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9174 - val_loss: 1.8993
# Epoch 409/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9168 - val_loss: 1.8973
# Epoch 410/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9100 - val_loss: 1.8903
# Epoch 411/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9035 - val_loss: 1.8962
# Epoch 412/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 2s 34ms/step - loss: 1.9239 - val_loss: 1.8934
# Epoch 413/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9188 - val_loss: 1.8846
# Epoch 414/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9184 - val_loss: 1.8781
# Epoch 415/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9188 - val_loss: 1.8834
# Epoch 416/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9236 - val_loss: 1.8856
# Epoch 417/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9201 - val_loss: 1.8905
# Epoch 418/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9196 - val_loss: 1.8922
# Epoch 419/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9190 - val_loss: 1.8967
# Epoch 420/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9154 - val_loss: 1.8970
# Epoch 421/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9121 - val_loss: 1.9015
# Epoch 422/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 17ms/step - loss: 1.9079 - val_loss: 1.8934
# Epoch 423/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9253 - val_loss: 1.8787
# Epoch 424/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9158 - val_loss: 1.8841
# Epoch 425/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9139 - val_loss: 1.8877
# Epoch 426/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 22ms/step - loss: 1.9232 - val_loss: 1.8839
# Epoch 427/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9225 - val_loss: 1.8939
# Epoch 428/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 33ms/step - loss: 1.9193 - val_loss: 1.8946
# Epoch 429/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 3s 43ms/step - loss: 1.9213 - val_loss: 1.9061
# Epoch 430/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 35ms/step - loss: 1.9421 - val_loss: 1.8935
# Epoch 431/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 37ms/step - loss: 1.9161 - val_loss: 1.8849
# Epoch 432/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9189 - val_loss: 1.8919
# Epoch 433/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9108 - val_loss: 1.8895
# Epoch 434/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9223 - val_loss: 1.8884
# Epoch 435/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9154 - val_loss: 1.8997
# Epoch 436/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9282 - val_loss: 1.8932
# Epoch 437/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9055 - val_loss: 1.8988
# Epoch 438/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9071 - val_loss: 1.8935
# Epoch 439/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9255 - val_loss: 1.8991
# Epoch 440/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9185 - val_loss: 1.8905
# Epoch 441/500
# 250/250 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9202 - val_loss: 1.8843
# Epoch 442/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9241 - val_loss: 1.8929
# Epoch 443/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 19ms/step - loss: 1.9173 - val_loss: 1.9005
# Epoch 444/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 18ms/step - loss: 1.9052 - val_loss: 1.9030
# Epoch 445/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9080 - val_loss: 1.8939
# Epoch 446/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9220 - val_loss: 1.8900
# Epoch 447/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 23ms/step - loss: 1.9205 - val_loss: 1.8810
# Epoch 448/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9069 - val_loss: 1.8981
# Epoch 449/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9314 - val_loss: 1.8869
# Epoch 450/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 20ms/step - loss: 1.9200 - val_loss: 1.8959
# Epoch 451/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9248 - val_loss: 1.8951
# Epoch 452/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9203 - val_loss: 1.8972
# Epoch 453/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9223 - val_loss: 1.8806
# Epoch 454/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9143 - val_loss: 1.8795
# Epoch 455/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9199 - val_loss: 1.8826
# Epoch 456/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 28ms/step - loss: 1.9263 - val_loss: 1.8873
# Epoch 457/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9168 - val_loss: 1.9034
# Epoch 458/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9271 - val_loss: 1.8984
# Epoch 459/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 36ms/step - loss: 1.9201 - val_loss: 1.8924
# Epoch 460/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9244 - val_loss: 1.8807
# Epoch 461/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 32ms/step - loss: 1.9301 - val_loss: 1.8835
# Epoch 462/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9202 - val_loss: 1.8880
# Epoch 463/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9218 - val_loss: 1.8858
# Epoch 464/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9208 - val_loss: 1.8912
# Epoch 465/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9340 - val_loss: 1.8928
# Epoch 466/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 30ms/step - loss: 1.9126 - val_loss: 1.8962
# Epoch 467/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9253 - val_loss: 1.9112
# Epoch 468/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9207 - val_loss: 1.8899
# Epoch 469/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9141 - val_loss: 1.8861
# Epoch 470/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 3s 42ms/step - loss: 1.9235 - val_loss: 1.8986
# Epoch 471/500
# 250/250 [==============================] - 1s 5ms/step
# 63/63 [==============================] - 3s 45ms/step - loss: 1.9205 - val_loss: 1.9060
# Epoch 472/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 3s 47ms/step - loss: 1.9235 - val_loss: 1.8952
# Epoch 473/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 37ms/step - loss: 1.9086 - val_loss: 1.8959
# Epoch 474/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 33ms/step - loss: 1.9286 - val_loss: 1.9065
# Epoch 475/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 32ms/step - loss: 1.9184 - val_loss: 1.9025
# Epoch 476/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9180 - val_loss: 1.9018
# Epoch 477/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 35ms/step - loss: 1.9397 - val_loss: 1.8929
# Epoch 478/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9095 - val_loss: 1.8917
# Epoch 479/500
# 250/250 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 1s 21ms/step - loss: 1.9259 - val_loss: 1.8922
# Epoch 480/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9131 - val_loss: 1.8854
# Epoch 481/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9294 - val_loss: 1.8882
# Epoch 482/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9251 - val_loss: 1.8895
# Epoch 483/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9326 - val_loss: 1.8867
# Epoch 484/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9121 - val_loss: 1.8953
# Epoch 485/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9207 - val_loss: 1.8866
# Epoch 486/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 24ms/step - loss: 1.9301 - val_loss: 1.8923
# Epoch 487/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9184 - val_loss: 1.8908
# Epoch 488/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9164 - val_loss: 1.8792
# Epoch 489/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9299 - val_loss: 1.8756
# Epoch 490/500
# 250/250 [==============================] - 1s 4ms/step
# 63/63 [==============================] - 3s 44ms/step - loss: 1.9189 - val_loss: 1.8730
# Epoch 491/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 33ms/step - loss: 1.9203 - val_loss: 1.8837
# Epoch 492/500
# 250/250 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 2s 31ms/step - loss: 1.9255 - val_loss: 1.8831
# Epoch 493/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 29ms/step - loss: 1.9082 - val_loss: 1.8877
# Epoch 494/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 26ms/step - loss: 1.9241 - val_loss: 1.8963
# Epoch 495/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9157 - val_loss: 1.9030
# Epoch 496/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9167 - val_loss: 1.8990
# Epoch 497/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 25ms/step - loss: 1.9210 - val_loss: 1.9040
# Epoch 498/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 2s 27ms/step - loss: 1.9181 - val_loss: 1.8941
# Epoch 499/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9247 - val_loss: 1.8800
# Epoch 500/500
# 250/250 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 24ms/step - loss: 1.9141 - val_loss: 1.8943

# %%
# After training, create a DataFrame with the logged data
results_df = pd.DataFrame({
    'Epoch': range(1, len(custom_callback.train_losses) + 1),
    'Training_Loss': custom_callback.train_losses,
    'Validation_Loss': custom_callback.val_losses,
    'Epoch_Run_Time(s)': custom_callback.epoch_times,
    'Last_Prediction': custom_callback.predictions
})

# Save the DataFrame to a CSV file
results_df.to_csv('model_performance.csv', index=False)

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error
# Assuming you have already trained your model and obtained predictions for both validation and test data
y_pred_val = model.predict(X_val)  # Predictions for validation data
y_pred_test = model.predict(X_test)  # Predictions for test data
y_pred_train = model.predict(X_train)  # Predictions for training data


# Calculate R-squared for both sets
r_squared_val = r2_score(y_val, y_pred_val)
r_squared_test = r2_score(y_test, y_pred_test)
r_squared_train = r2_score(y_train, y_pred_train)


# Calculate MAE for all three datasets
mae_val = mean_absolute_error(y_val, y_pred_val)
mae_test = mean_absolute_error(y_test, y_pred_test)
mae_train = mean_absolute_error(y_train, y_pred_train)

# Calculate MSE for all three datasets
mse_val = mean_squared_error(y_val, y_pred_val)
mse_test = mean_squared_error(y_test, y_pred_test)
mse_train = mean_squared_error(y_train, y_pred_train)



print(f"Accuracy on Validation Data: {r_squared_val * 100}")
print(f"Accuracy on Test Data: {r_squared_test * 100}")
print(f"Accuracy on Train Data: {r_squared_test * 100}")

print(f"Mean Absolute Error (MAE) on Validation Data: {mae_val:.4f}")
print(f"Mean Absolute Error (MAE) on Test Data: {mae_test:.4f}")
print(f"Mean Absolute Error (MAE) on Training Data: {mae_train:.4f}")

print(f"Mean Squared Error (MSE) on Validation Data: {mse_val:.4f}")
print(f"Mean Squared Error (MSE) on Test Data: {mse_test:.4f}")
print(f"Mean Squared Error (MSE) on Training Data: {mse_train:.4f}")
# Out:
# 525/525 [==============================] - 1s 1ms/step
# 750/750 [==============================] - 1s 1ms/step
# 1225/1225 [==============================] - 2s 1ms/step
# Accuracy on Validation Data: 99.29509713686546
# Accuracy on Test Data: 99.28769351170854
# Accuracy on Train Data: 99.28769351170854
# Mean Absolute Error (MAE) on Validation Data: 0.1471
# Mean Absolute Error (MAE) on Test Data: 0.1478
# Mean Absolute Error (MAE) on Training Data: 0.1283
# Mean Squared Error (MSE) on Validation Data: 0.0341
# Mean Squared Error (MSE) on Test Data: 0.0344
# Mean Squared Error (MSE) on Training Data: 0.0259
